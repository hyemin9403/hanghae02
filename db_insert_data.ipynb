# %%
{
    "dessert_name": "초콜렛",
    "img": "https://mp-seoul-image-production-s3.mangoplate.com/32525_1613705532160684.jpg?fit=around|738:738&crop=738:738;*,*&output-format=jpg&output-quality=80",
    "comment": "맛있어요",
    "time": "2021-01-01",
    "count_like": 0
}
{
    "dessert_name": "과일케이크",
    "img": "https://mp-seoul-image-production-s3.mangoplate.com/280896/1100616_1623213583892_21861?fit=around|738:738&crop=738:738;*,*&output-format=jpg&output-quality=80",
    "comment": "맛있어요",
    "time": "2021-01-02",
    "count_like": 0
}
{
    "dessert_name": "무스케이크",
    "img": "https://mp-seoul-image-production-s3.mangoplate.com/1592769_1618712611702859.jpg?fit=around|738:738&crop=738:738;*,*&output-format=jpg&output-quality=80",
    "comment": "맛있어요",
    "time": "2021-01-03",
    "count_like": 0
}
{
    "dessert_name": "생크림케이크",
    "img": "https://mp-seoul-image-production-s3.mangoplate.com/722502_1623969942229164.jpg?fit=around|738:738&crop=738:738;*,*&output-format=jpg&output-quality=80",
    "comment": "맛있어요",
    "time": "2021-01-04",
    "count_like": 0
}
{
    "dessert_name": "크로플",
    "img": "https://mp-seoul-image-production-s3.mangoplate.com/1601255_1621035366126877.jpg?fit=around|738:738&crop=738:738;*,*&output-format=jpg&output-quality=80",
    "comment": "맛있어요",
    "time": "2021-01-05",
    "count_like": 0
}
{
    "dessert_name": "스콘",
    "img": "https://mp-seoul-image-production-s3.mangoplate.com/495395_1612410511446049.jpg?fit=around|738:738&crop=738:738;*,*&output-format=jpg&output-quality=80",
    "comment": "맛있어요",
    "time": "2021-01-06",
    "count_like": 0
}
{
    "dessert_name": "티라미수",
    "img": "https://mp-seoul-image-production-s3.mangoplate.com/63413_1620998445251311.jpg?fit=around|738:738&crop=738:738;*,*&output-format=jpg&output-quality=80",
    "comment": "맛있어요",
    "time": "2021-01-07",
    "count_like": 0
}
{
    "dessert_name": "마카롱",
    "img": "https://mp-seoul-image-production-s3.mangoplate.com/585/810572_1556009438587_99034?fit=around|738:738&crop=738:738;*,*&output-format=jpg&output-quality=80",
    "comment": "맛있어요",
    "time": "2021-01-08",
    "count_like": 0
}
{
    "dessert_name": "타르트",
    "img": "https://mp-seoul-image-production-s3.mangoplate.com/253750/488522_1597163611552_6834?fit=around|738:738&crop=738:738;*,*&output-format=jpg&output-quality=80",
    "comment": "맛있어요",
    "time": "2021-01-09",
    "count_like": 0
}
{
    "dessert_name": "아이스크림",
    "img": "https://mp-seoul-image-production-s3.mangoplate.com/573810_1624509305955146.jpg?fit=around|738:738&crop=738:738;*,*&output-format=jpg&output-quality=80",
    "comment": "시원해요",
    "time": "2021-01-10",
    "count_like": 0
}
